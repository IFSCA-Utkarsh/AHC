# %%
# !git clone https://github.com/IFSCA-Utkarsh/Youtube.git

# %%
# %cd Youtube

# %%
# %run main.py

# %%
from youtube_studio.local_player_app import LocalPlayerApp
LocalPlayerApp().display()
