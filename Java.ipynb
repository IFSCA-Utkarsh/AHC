// %%
!apt-get update -q
!apt-get install -q -y openjdk-11-jdk-headless

// %%
!curl -L https://github.com/SpencerPark/IJava/releases/download/v1.3.0/ijava-1.3.0.zip -o ijava-kernel.zip

// %%
!unzip -q ijava-kernel.zip -d ijava-kernel
!cd ijava-kernel && python3 install.py --sys-prefix

// %%
!rm -rf ijava-kernel ijava-kernel.zip

// %%
!jupyter kernelspec list

// %%
%%writefile Main.java
public class Main {
    public static void main(String[] args) {
        System.out.println("Hello, World! Java is running perfectly via Bash override.");

        // Quick math test
        int a = 10;
        int b = 20;
        System.out.println("Sum: " + (a + b));
    }
}

// %%
!javac Main.java && java Main

// %%
!echo 'System.out.println("Quick Java Test: " + Math.sqrt(144));' | jshell -
